# %% [raw]
# Principles of computer science II - Third assignments: Insertion sort
# Anastasia Sonego - 1879436

# %%
A = list(map(int, input().split()))
def insertionSort(A):
    swaps=0
    n=len(A)
    for i in range(1, n):
        k = i
        while k > 0 and A[k] < A[k-1]:
            A[k], A[k-1] = A[k-1], A[k]
            k-=1
            swaps+=1
    return(swaps)
print(insertionSort(A))
# Out:
# 859 -11633 75953 68387 10566 -46377 -98045 46276 -95037 14116 -66355 22943 -78030 87040 -62765 3712 59043 -42133 53626 -47012 -81733 70277 98837 36881 29922 -32216 16055 -54430 65845 21297 -19138 29018 -25658 -26976 84824 87668 -93018 -90268 65771 -29255 21876 -14968 23912 79364 -76190 -38348 94654 -87655 77707 15656 94386 -68549 -24560 69709 -18863 866 -92994 16474 -9628 -38255 46622 -59727 -90668 2110 -81798 -12656 -96776 -41330 80949 59779 91535 -34338 64436 -78263 23993 97454 -99575 -33822 67122 -46524 -19355 34219 32336 -93459 29870 52349 4790 -51197 21965 64612 -75806 -41162 -67536 -20438 -33401 -25456 -99959 49768 -31647 -95973 55743 -71121 -79524 1153 47133 58904 -72806 24590 -25656 -43989 -96973 -25573 9165 -70458 -32801 38277 6945 -14138 -21714 80058 -20860 31157 78923 -87620 18926 9499 -54853 18863 48155 98172 -51316 -6730 -18162 -67212 39752 -66352 -32473 -1756 58532 -69084 11500 -10979 -39597 -14548 -2884 90188 71290 -64257 -6663 -39972 20114 35590 -83085 -54872 -13676 1
# ...
