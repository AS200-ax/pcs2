# %% [raw]
# # Principles of Computer Science II - Fifth Assignment
# Anastasia Sonego - 1879436 - grph

# %%
from Bio import SeqIO

def grph(d):
    for x in d:
        for y in d:
            if x!=y and d[x][-3:] == d[y][:3]: print(x,y)

d={}
for data in SeqIO.parse('rosalind_grph.txt','fasta'):
    d[data.id]=data.seq
grph(d)
# Out:
# Rosalind_5773 Rosalind_6231
# Rosalind_5151 Rosalind_7664
# Rosalind_5274 Rosalind_7117
# Rosalind_5274 Rosalind_3454
# Rosalind_9353 Rosalind_1827
# Rosalind_9353 Rosalind_9844
# Rosalind_2511 Rosalind_1585
# Rosalind_2511 Rosalind_0244
# Rosalind_1883 Rosalind_7535
# Rosalind_1883 Rosalind_7009
# Rosalind_1883 Rosalind_7528
# Rosalind_2738 Rosalind_3639
# Rosalind_2738 Rosalind_9353
# Rosalind_2738 Rosalind_9953
# Rosalind_4027 Rosalind_4042
# Rosalind_4027 Rosalind_4022
# Rosalind_1585 Rosalind_3446
# Rosalind_1585 Rosalind_4038
# Rosalind_6541 Rosalind_1379
# Rosalind_6541 Rosalind_6508
# Rosalind_1173 Rosalind_7117
# Rosalind_1173 Rosalind_3454
# Rosalind_8404 Rosalind_6554
# Rosalind_5286 Rosalind_0978
# Rosalind_5286 Rosalind_8468
# Rosalind_3862 Rosalind_4422
# Rosalind_3862 Rosalind_6969
# Rosalind_3862 Rosalind_0018
# Rosalind_5219 Rosalind_7193
# Rosalind_2294 Rosalind_5773
# Rosalind_2294 Rosalind_5151
# Rosalind_2294 Rosalind_7197
# Rosalind_4620 Rosalind_2026
# ...
