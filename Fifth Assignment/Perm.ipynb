# %% [raw]
# Principles of Computer Science II - Fifth Assignment
# Anastasia Sonego - 1879436 - perm

# %%
import math
from itertools import permutations

def perm(n):
    perms=math.factorial(n)
    print(perms)
    res=permutations(range(1,n+1))
    print(*res)

data=open('rosalind_perm.txt','r').read()
perm(int(data))
# Out:
# 120
# ...
